# %% [markdown]
# ## yolo v3 object detection model

# %% [markdown]
# # we will first use some images to detect objects

# %%
import numpy as np
import cv2

confidenceThreshold = 0.5
NMSThreshold = 0.3

modelConfiguration = 'yolov3.cfg'
modelWeights = 'yolov3.weights'

labelsPath = 'coco.names'
labels = open(labelsPath).read().strip().split('\n')

np.random.seed(10)
COLORS = np.random.randint(0, 255, size=(len(labels), 3), dtype="uint8")

net = cv2.dnn.readNetFromDarknet(modelConfiguration, modelWeights)
#first we will look for house interior image
image = cv2.imread('house.jpeg')
(H, W) = image.shape[:2]

#Determine output layer names
layerName = net.getLayerNames()
layerName = [layerName[i[0] - 1] for i in net.getUnconnectedOutLayers()]

blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416), swapRB = True, crop = False)
net.setInput(blob)
layersOutputs = net.forward(layerName)

boxes = []
confidences = []
classIDs = []

for output in layersOutputs:
    for detection in output:
        scores = detection[5:]
        classID = np.argmax(scores)
        confidence = scores[classID]
        if confidence > confidenceThreshold:
            box = detection[0:4] * np.array([W, H, W, H])
            (centerX, centerY,  width, height) = box.astype('int')
            x = int(centerX - (width/2))
            y = int(centerY - (height/2))

            boxes.append([x, y, int(width), int(height)])
            confidences.append(float(confidence))
            classIDs.append(classID)

#Apply Non Maxima Suppression
detectionNMS = cv2.dnn.NMSBoxes(boxes, confidences, confidenceThreshold, NMSThreshold)

if(len(detectionNMS) > 0):
    for i in detectionNMS.flatten():
        (x, y) = (boxes[i][0], boxes[i][1])
        (w, h) = (boxes[i][2], boxes[i][3])

        color = [int(c) for c in COLORS[classIDs[i]]]
        cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
        text = '{}: {:.4f}'.format(labels[classIDs[i]], confidences[i])
        cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)


cv2.imshow('Image', image)
cv2.waitKey(0)

# %%
import numpy as np
import cv2

confidenceThreshold = 0.5
NMSThreshold = 0.3

modelConfiguration = 'yolov3.cfg'
modelWeights = 'yolov3.weights'

labelsPath = 'coco.names'
labels = open(labelsPath).read().strip().split('\n')

np.random.seed(10)
COLORS = np.random.randint(0, 255, size=(len(labels), 3), dtype="uint8")

net = cv2.dnn.readNetFromDarknet(modelConfiguration, modelWeights)
#next we will look for long vehicle detection in traffic
image = cv2.imread('long vehicles.jpeg')
(H, W) = image.shape[:2]

#Determine output layer names
layerName = net.getLayerNames()
layerName = [layerName[i[0] - 1] for i in net.getUnconnectedOutLayers()]

blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416), swapRB = True, crop = False)
net.setInput(blob)
layersOutputs = net.forward(layerName)

boxes = []
confidences = []
classIDs = []

for output in layersOutputs:
    for detection in output:
        scores = detection[5:]
        classID = np.argmax(scores)
        confidence = scores[classID]
        if confidence > confidenceThreshold:
            box = detection[0:4] * np.array([W, H, W, H])
            (centerX, centerY,  width, height) = box.astype('int')
            x = int(centerX - (width/2))
            y = int(centerY - (height/2))

            boxes.append([x, y, int(width), int(height)])
            confidences.append(float(confidence))
            classIDs.append(classID)

#Apply Non Maxima Suppression
detectionNMS = cv2.dnn.NMSBoxes(boxes, confidences, confidenceThreshold, NMSThreshold)

if(len(detectionNMS) > 0):
    for i in detectionNMS.flatten():
        (x, y) = (boxes[i][0], boxes[i][1])
        (w, h) = (boxes[i][2], boxes[i][3])

        color = [int(c) for c in COLORS[classIDs[i]]]
        cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
        text = '{}: {:.4f}'.format(labels[classIDs[i]], confidences[i])
        cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

cv2.imshow('Image', image)
cv2.waitKey(0)

# %% [markdown]
# # Next we will use some test video to detect object present in each frame of the video

# %%
import numpy as np
import cv2

confidenceThreshold = 0.5
NMSThreshold = 0.3

modelConfiguration = 'yolov3.cfg'
modelWeights = 'yolov3.weights'

labelsPath = 'coco.names'
labels = open(labelsPath).read().strip().split('\n')

np.random.seed(10)
COLORS = np.random.randint(0, 255, size=(len(labels), 3), dtype="uint8")

net = cv2.dnn.readNetFromDarknet(modelConfiguration, modelWeights)

outputLayer = net.getLayerNames()
outputLayer = [outputLayer[i[0] - 1] for i in net.getUnconnectedOutLayers()]
#first we will use test1.mp4 to test our model
video = cv2.VideoCapture('test1.mp4')
writer = None
(W, H) = (None, None)

try:
    prop = cv2.CAP_PROP_FRAME_COUNT
    total = int(video.get(prop))
    print("[INFO] {} total frames in video".format(total))
except:
    printf("Could not determine no. of frames in video")

count = 0
while True:
    (ret, frame) = video.read()
    if not ret:
        break
    if W is None or H is None:
        (H,W) = frame.shape[:2]

    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416), swapRB = True, crop = False)
    net.setInput(blob)
    layersOutputs = net.forward(outputLayer)

    boxes = []
    confidences = []
    classIDs = []

    for output in layersOutputs:
        for detection in output:
            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > confidenceThreshold:
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY,  width, height) = box.astype('int')
                x = int(centerX - (width/2))
                y = int(centerY - (height/2))

                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)

    #Apply Non Maxima Suppression
    detectionNMS = cv2.dnn.NMSBoxes(boxes, confidences, confidenceThreshold, NMSThreshold)
    if(len(detectionNMS) > 0):
        for i in detectionNMS.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
            text = '{}: {:.4f}'.format(labels[classIDs[i]], confidences[i])
            cv2.putText(frame, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            if writer is None:
                fourcc = cv2.VideoWriter_fourcc(*'MJPG')
                writer = cv2.VideoWriter('test1_output.avi', fourcc, 30, (frame.shape[1], frame.shape[0]), True)
    if writer is not None:
        writer.write(frame)
        print("Writing frame" , count+1)
        count = count + 1

writer.release()
video.release()
# Out:
# [INFO] 576 total frames in video
# Writing frame 1
# Writing frame 2
# Writing frame 3
# Writing frame 4
# Writing frame 5
# Writing frame 6
# Writing frame 7
# Writing frame 8
# Writing frame 9
# Writing frame 10
# Writing frame 11
# Writing frame 12
# Writing frame 13
# Writing frame 14
# Writing frame 15
# Writing frame 16
# Writing frame 17
# Writing frame 18
# Writing frame 19
# Writing frame 20
# Writing frame 21
# Writing frame 22
# Writing frame 23
# Writing frame 24
# Writing frame 25
# Writing frame 26
# Writing frame 27
# Writing frame 28
# Writing frame 29
# Writing frame 30
# Writing frame 31
# Writing frame 32
# Writing frame 33
# Writing frame 34
# Writing frame 35
# Writing frame 36
# Writing frame 37
# Writing frame 38
# Writing frame 39
# Writing frame 40
# Writing frame 41
# Writing frame 42
# Writing frame 43
# Writing frame 44
# Writing frame 45
# Writing frame 46
# Writing frame 47
# Writing frame 48
# Writing frame 49
# Writing frame 50
# Writing frame 51
# Writing frame 52
# Writing frame 53
# Writing frame 54
# Writing frame 55
# Writing frame 56
# Writing frame 57
# Writing frame 58
# Writing frame 59
# Writing frame 60
# Writing frame 61
# Writing frame 62
# Writing frame 63
# Writing frame 64
# Writing frame 65
# Writing frame 66
# Writing frame 67
# Writing frame 68
# Writing frame 69
# Writing frame 70
# Writing frame 71
# Writing frame 72
# Writing frame 73
# Writing frame 74
# Writing frame 75
# Writing frame 76
# Writing frame 77
# Writing frame 78
# Writing frame 79
# Writing frame 80
# Writing frame 81
# Writing frame 82
# Writing frame 83
# Writing frame 84
# Writing frame 85
# Writing frame 86
# Writing frame 87
# Writing frame 88
# Writing frame 89
# Writing frame 90
# Writing frame 91
# Writing frame 92
# Writing frame 93
# Writing frame 94
# Writing frame 95
# Writing frame 96
# Writing frame 97
# Writing frame 98
# Writing frame 99
# Writing frame 100
# Writing frame 101
# Writing frame 102
# Writing frame 103
# Writing frame 104
# Writing frame 105
# Writing frame 106
# Writing frame 107
# Writing frame 108
# Writing frame 109
# Writing frame 110
# Writing frame 111
# Writing frame 112
# Writing frame 113
# Writing frame 114
# Writing frame 471
# Writing frame 472
# Writing frame 473
# Writing frame 474
# Writing frame 475
# Writing frame 476
# Writing frame 477
# Writing frame 478
# Writing frame 479
# Writing frame 480
# Writing frame 481
# Writing frame 482
# Writing frame 483
# Writing frame 484
# Writing frame 485
# Writing frame 486
# Writing frame 487
# Writing frame 488
# Writing frame 489
# Writing frame 490
# Writing frame 491
# Writing frame 492
# Writing frame 493
# Writing frame 494
# Writing frame 495
# Writing frame 496
# Writing frame 497
# Writing frame 498
# Writing frame 499
# Writing frame 500
# Writing frame 501
# Writing frame 502
# Writing frame 503
# Writing frame 504
# Writing frame 505
# Writing frame 506
# Writing frame 507
# Writing frame 508
# Writing frame 509
# Writing frame 510
# Writing frame 511
# Writing frame 512
# Writing frame 513
# Writing frame 514
# Writing frame 515
# Writing frame 516
# Writing frame 517
# Writing frame 518
# Writing frame 519
# Writing frame 520
# Writing frame 521
# Writing frame 522
# Writing frame 523
# Writing frame 524
# Writing frame 525
# Writing frame 526
# Writing frame 527
# Writing frame 528
# Writing frame 529
# Writing frame 530
# Writing frame 531
# Writing frame 532
# Writing frame 533
# Writing frame 534
# Writing frame 535
# Writing frame 536
# Writing frame 537
# Writing frame 538
# Writing frame 539
# Writing frame 540
# Writing frame 541
# Writing frame 542
# Writing frame 543
# Writing frame 544
# Writing frame 545
# Writing frame 546
# Writing frame 547
# Writing frame 548
# Writing frame 549
# Writing frame 550
# Writing frame 551
# Writing frame 552
# Writing frame 553
# Writing frame 554
# Writing frame 555
# Writing frame 556
# Writing frame 557
# Writing frame 558
# Writing frame 559
# Writing frame 560
# Writing frame 561
# Writing frame 562
# Writing frame 563
# Writing frame 564
# Writing frame 565
# Writing frame 566
# Writing frame 567
# Writing frame 568
# Writing frame 569
# Writing frame 570
# Writing frame 571
# Writing frame 572
# Writing frame 573
# Writing frame 574
# Writing frame 575
# Writing frame 576

# %%
import numpy as np
import cv2

confidenceThreshold = 0.5
NMSThreshold = 0.3

modelConfiguration = 'yolov3.cfg'
modelWeights = 'yolov3.weights'

labelsPath = 'coco.names'
labels = open(labelsPath).read().strip().split('\n')

np.random.seed(10)
COLORS = np.random.randint(0, 255, size=(len(labels), 3), dtype="uint8")

net = cv2.dnn.readNetFromDarknet(modelConfiguration, modelWeights)

outputLayer = net.getLayerNames()
outputLayer = [outputLayer[i[0] - 1] for i in net.getUnconnectedOutLayers()]
#first we will use test2.mp4 to test our model
video = cv2.VideoCapture('test2.mp4')
writer = None
(W, H) = (None, None)

try:
    prop = cv2.CAP_PROP_FRAME_COUNT
    total = int(video.get(prop))
    print("[INFO] {} total frames in video".format(total))
except:
    printf("Could not determine no. of frames in video")

count = 0
while True:
    (ret, frame) = video.read()
    if not ret:
        break
    if W is None or H is None:
        (H,W) = frame.shape[:2]

    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416), swapRB = True, crop = False)
    net.setInput(blob)
    layersOutputs = net.forward(outputLayer)

    boxes = []
    confidences = []
    classIDs = []

    for output in layersOutputs:
        for detection in output:
            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > confidenceThreshold:
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY,  width, height) = box.astype('int')
                x = int(centerX - (width/2))
                y = int(centerY - (height/2))

                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)

    #Apply Non Maxima Suppression
    detectionNMS = cv2.dnn.NMSBoxes(boxes, confidences, confidenceThreshold, NMSThreshold)
    if(len(detectionNMS) > 0):
        for i in detectionNMS.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
            text = '{}: {:.4f}'.format(labels[classIDs[i]], confidences[i])
            cv2.putText(frame, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

# Writing frame 341
# Writing frame 342
# Writing frame 343
# Writing frame 344
# Writing frame 345
# Writing frame 346
# Writing frame 347
# Writing frame 348
# Writing frame 349
# Writing frame 350
# Writing frame 351
# Writing frame 352
# Writing frame 353
# Writing frame 354
# Writing frame 355
# Writing frame 356
# Writing frame 357
# Writing frame 358
# Writing frame 359
# Writing frame 360
# Writing frame 361
# Writing frame 362
# Writing frame 363
# Writing frame 364
# Writing frame 365
# Writing frame 366
# Writing frame 367
# Writing frame 368
# Writing frame 369
# Writing frame 370
# Writing frame 371
# Writing frame 372
# Writing frame 373
# Writing frame 374
# Writing frame 375
# Writing frame 376
# Writing frame 377
# Writing frame 378
# Writing frame 379
# Writing frame 380
# Writing frame 381
# Writing frame 382
# Writing frame 383
# Writing frame 384
# Writing frame 385
# Writing frame 386
# Writing frame 387
# Writing frame 388
# Writing frame 389
# Writing frame 390
# Writing frame 391
# Writing frame 392
# Writing frame 393
# Writing frame 394
# Writing frame 395
# Writing frame 396
# Writing frame 397
# Writing frame 398
# Writing frame 399
# Writing frame 400
# Writing frame 401
# Writing frame 402
# Writing frame 403
# Writing frame 404
# Writing frame 405
# Writing frame 406
# Writing frame 407
# Writing frame 408
# Writing frame 409
# Writing frame 410
# Writing frame 411
# Writing frame 412
# Writing frame 413
# Writing frame 414
# Writing frame 415
# Writing frame 416
# Writing frame 417
# Writing frame 418
# Writing frame 419
# Writing frame 420
# Writing frame 421
# Writing frame 422
# Writing frame 423
# Writing frame 424
# Writing frame 425
# Writing frame 426
# Writing frame 427
# Writing frame 428
# Writing frame 429
# Writing frame 430
# Writing frame 431
# Writing frame 432
# Writing frame 433
# Writing frame 434
# Writing frame 435
# Writing frame 436
# Writing frame 437
# Writing frame 438
# Writing frame 439
# Writing frame 440
# Writing frame 441
# Writing frame 442
# Writing frame 443

# %% [markdown]
# # last we will detect object from webcam video input

# %%
import numpy as np
import cv2

confidenceThreshold = 0.5
NMSThreshold = 0.3

modelConfiguration = 'yolov3.cfg'
modelWeights = 'yolov3.weights'

labelsPath = 'coco.names'
labels = open(labelsPath).read().strip().split('\n')

np.random.seed(10)
COLORS = np.random.randint(0, 255, size=(len(labels), 3), dtype="uint8")

net = cv2.dnn.readNetFromDarknet(modelConfiguration, modelWeights)

outputLayer = net.getLayerNames()
outputLayer = [outputLayer[i[0] - 1] for i in net.getUnconnectedOutLayers()]

video_capture = cv2.VideoCapture(0)

(W, H) = (None, None)

while True:
    ret, frame = video_capture.read()
    frame = cv2.flip(frame, 1)
    if W is None or H is None:
        (H,W) = frame.shape[:2]

    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416), swapRB = True, crop = False)
    net.setInput(blob)
    layersOutputs = net.forward(outputLayer)

    boxes = []
    confidences = []
    classIDs = []

    for output in layersOutputs:
        for detection in output:
            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > confidenceThreshold:
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY,  width, height) = box.astype('int')
                x = int(centerX - (width/2))
                y = int(centerY - (height/2))

                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)

    #Apply Non Maxima Suppression
    detectionNMS = cv2.dnn.NMSBoxes(boxes, confidences, confidenceThreshold, NMSThreshold)
    if(len(detectionNMS) > 0):
        for i in detectionNMS.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
            text = '{}: {:.4f}'.format(labels[classIDs[i]], confidences[i])
            cv2.putText(frame, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    cv2.imshow('Output', frame)
    if(cv2.waitKey(1) & 0xFF == ord('q')):
        break

#Finally when video capture is over, release the video capture and destroyAllWindows
video_capture.release()
cv2.destroyAllWindows()
